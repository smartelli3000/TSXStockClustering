# %% [markdown]
# # Stock Clustering Analysis

# %% [markdown]
# ### Importing the required libraries

# %%
import pandas as pd
from yahoo_fin.stock_info import get_quote_data

# %% [markdown]
# ## Importing the required data

# %% [markdown]
# ### S&P/TSX Company tickers list

# %%
### Any ticker with a '.' must be replaced with a '-'.

# %%
# Reading the S&P/TSX companies csv file.
tsx_names = pd.read_csv('SnP_TSX_Companies_List.csv', squeeze=True)

# Adding '.TO' to the ending of each ticker to ensure all currency information received comes in CND.
TO = '.TO'

tsx_names_TO = []
for ticker in tsx_names:
    tsx_names_TO.append(str(ticker) + TO)
    
tsx_names = pd.Series(tsx_names_TO)

# %% [markdown]
# ### Gathering quote data from companies

# %%
# This searches and gets the stock quote data from yahoo finance.
dict1 = get_quote_data('TIH.TO')
dict2 = get_quote_data('AQN.TO')
dict3 = get_quote_data('BNS.TO')

# This takes the quote dictionaries and converts them into a DataFrame.
df1 = pd.DataFrame(dict1, index=['TIH.TO'])
df2 = pd.DataFrame(dict2, index=['AQN.TO'])
df3 = pd.DataFrame(dict3, index=['BNS.TO'])

# Empty DataFram to append all of the quotes acquired. 
dfFinal = pd.DataFrame()

# Appending the quotes acquired.
dfFinal = dfFinal.append(df1)
dfFinal = dfFinal.append(df2)
dfFinal = dfFinal.append(df3)

dfFinal

# df[['epsCurrentYear','sharesOutstanding']]  # This works for selecting columns

### Whats next?
### Now iterate this with all the tickers, and add them as a new row into a DataFrame.
# Out:
#        language region quoteType quoteSourceName  triggerable currency  \
# TIH.TO    en-US     US    EQUITY   Delayed Quote         True      CAD
# AQN.TO    en-US     US    EQUITY   Delayed Quote         True      CAD
# BNS.TO    en-US     US    EQUITY   Delayed Quote         True      CAD
#
#        exchange                        shortName  \
# TIH.TO      TOR                     TOROMONT IND
# AQN.TO      TOR  ALGONQUIN POWER AND UTILITIES C
# BNS.TO      TOR              BANK OF NOVA SCOTIA
#
#                                  longName messageBoardId  ...  \
# TIH.TO           Toromont Industries Ltd.   finmb_873897  ...
# AQN.TO  Algonquin Power & Utilities Corp.   finmb_882318  ...
# BNS.TO            The Bank of Nova Scotia   finmb_873647  ...
#
#        fiftyTwoWeekLowChangePercent fiftyTwoWeekRange  fiftyTwoWeekHighChange  \
# TIH.TO                     0.626780    61.09 - 100.71               -1.330002
# AQN.TO                     0.186350     16.85 - 22.67               -2.680000
# BNS.TO                     0.593769     49.11 - 80.16               -1.890007
#
#        fiftyTwoWeekHighChangePercent  fiftyTwoWeekLow fiftyTwoWeekHigh  \
# TIH.TO                     -0.013206            61.09           100.71
# AQN.TO                     -0.118218            16.85            22.67
# BNS.TO                     -0.023578            49.11            80.16
#
#         dividendDate  firstTradeDateMilliseconds  priceHint  symbol
# TIH.TO    1617235200                839943000000          2  TIH.TO
# AQN.TO    1618444800               1065706200000          2  AQN.TO
# BNS.TO    1619568000                789921000000          2  BNS.TO
#
# [3 rows x 70 columns]

# %%
get_quote_data('AP-UN.TO')
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': True,
#  'currency': 'CAD',
#  'trailingAnnualDividendRate': 1.65,
#  'trailingPE': 10.537313,
#  'trailingAnnualDividendYield': 0.039739884,
#  'epsTrailingTwelveMonths': 4.02,
#  'epsForward': 4.03,
#  'sharesOutstanding': 127259000,
#  'bookValue': 48.539,
#  'fiftyDayAverage': 41.60706,
#  'fiftyDayAverageChange': 0.75294113,
#  'fiftyDayAverageChangePercent': 0.018096475,
#  'twoHundredDayAverage': 38.628445,
#  'twoHundredDayAverageChange': 3.731556,
#  'twoHundredDayAverageChangePercent': 0.09660125,
#  'marketCap': 5390691328,
#  'forwardPE': 10.511166,
#  'priceToBook': 0.8727003,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 15,
#  'averageAnalystRating': '2.0 - Buy',
#  'firstTradeDateMilliseconds': 1216906200000,
#  'priceHint': 2,
#  'regularMarketChange': 0.84000015,
#  'regularMarketChangePercent': 2.0231218,
#  'regularMarketTime': 1619553600,
#  'regularMarketPrice': 42.36,
#  'regularMarketDayHigh': 42.43,
#  'regularMarketDayRange': '41.45 - 42.43',
#  'regularMarketDayLow': 41.45,
#  'regularMarketVolume': 215132,
#  'regularMarketPreviousClose': 41.52,
#  'bid': 42.28,
#  'ask': 42.4,
#  'bidSize': 0,
#  'askSize': 0,
#  'fullExchangeName': 'Toronto',
#  'financialCurrency': 'CAD',
#  'regularMarketOpen': 41.45,
#  'averageDailyVolume3Month': 323583,
#  'averageDailyVolume10Day': 231750,
#  'fiftyTwoWeekLowChange': 10.860001,
#  'fiftyTwoWeekLowChangePercent': 0.34476194,
#  'fiftyTwoWeekRange': '31.5 - 45.68',
#  'fiftyTwoWeekHighChange': -3.3199997,
#  'fiftyTwoWeekHighChangePercent': -0.072679505,
#  'fiftyTwoWeekLow': 31.5,
#  'fiftyTwoWeekHigh': 45.68,
#  'dividendDate': 1621209600,
#  'marketState': 'POSTPOST',
#  'exchange': 'TOR',
#  'shortName': 'ALLIED PROPERTIES REAL ESTATE I',
#  'longName': 'Allied Properties Real Estate Investment Trust',
#  'messageBoardId': 'finmb_4613444',
#  'exchangeTimezoneName': 'America/Toronto',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'ca_market',
#  'esgPopulated': False,
#  'tradeable': False,
#  'symbol': 'AP-UN.TO'}

# %%
df = pd.DataFrame()

for ticker in tsx_names:
    tickerDict = get_quote_data(ticker)
    tickerdf = pd.DataFrame(dict1, index=[ticker])
    print(tickerdf)

    
#     tickerdf = pd.DataFrame(tickerDict, index=[ticker])
#     df.append(tickerdf)
# Out:
#       language region quoteType quoteSourceName  triggerable currency  \
# AT.TO    en-US     US    EQUITY   Delayed Quote         True      CAD
#
#       exchange     shortName                  longName messageBoardId  ...  \
# AT.TO      TOR  TOROMONT IND  Toromont Industries Ltd.   finmb_873897  ...
#
#       fiftyTwoWeekLowChangePercent fiftyTwoWeekRange  fiftyTwoWeekHighChange  \
# AT.TO                      0.62678    61.09 - 100.71               -1.330002
#
#       fiftyTwoWeekHighChangePercent  fiftyTwoWeekLow fiftyTwoWeekHigh  \
# AT.TO                     -0.013206            61.09           100.71
#
#        dividendDate  firstTradeDateMilliseconds  priceHint  symbol
# AT.TO    1617235200                839943000000          2  TIH.TO
#
# [1 rows x 70 columns]
#        language region quoteType quoteSourceName  triggerable currency  \
# ARE.TO    en-US     US    EQUITY   Delayed Quote         True      CAD
#
#        exchange     shortName                  longName messageBoardId  ...  \
# ARE.TO      TOR  TOROMONT IND  Toromont Industries Ltd.   finmb_873897  ...
#
#        fiftyTwoWeekLowChangePercent fiftyTwoWeekRange  fiftyTwoWeekHighChange  \
# ARE.TO                      0.62678    61.09 - 100.71               -1.330002
#
#        fiftyTwoWeekHighChangePercent  fiftyTwoWeekLow fiftyTwoWeekHigh  \
# ARE.TO                     -0.013206            61.09           100.71
#
#         dividendDate  firstTradeDateMilliseconds  priceHint  symbol
# ARE.TO    1617235200                839943000000          2  TIH.TO
#
# [1 rows x 70 columns]
#        language region quoteType quoteSourceName  triggerable currency  \
# AEM.TO    en-US     US    EQUITY   Delayed Quote         True      CAD
#
#        exchange     shortName                  longName messageBoardId  ...  \
# AEM.TO      TOR  TOROMONT IND  Toromont Industries Ltd.   finmb_873897  ...
#
#        fiftyTwoWeekLowChangePercent fiftyTwoWeekRange  fiftyTwoWeekHighChange  \
# AEM.TO                      0.62678    61.09 - 100.71               -1.330002
#
#        fiftyTwoWeekHighChangePercent  fiftyTwoWeekLow fiftyTwoWeekHigh  \
# AEM.TO                     -0.013206            61.09           100.71
#
#         dividendDate  firstTradeDateMilliseconds  priceHint  symbol
# AEM.TO    1617235200                839943000000          2  TIH.TO
#
# [1 rows x 70 columns]
#       language region quoteType quoteSourceName  triggerable currency  \
# AC.TO    en-US     US    EQUITY   Delayed Quote         True      CAD
#
#       exchange     shortName                  longName messageBoardId  ...  \
# AC.TO      TOR  TOROMONT IND  Toromont Industries Ltd.   finmb_873897  ...
#
#       fiftyTwoWeekLowChangePercent fiftyTwoWeekRange  fiftyTwoWeekHighChange  \
# AC.TO                      0.62678    61.09 - 100.71               -1.330002
#
#       fiftyTwoWeekHighChangePercent  fiftyTwoWeekLow fiftyTwoWeekHigh  \
# AC.TO                     -0.013206            61.09           100.71
#
#        dividendDate  firstTradeDateMilliseconds  priceHint  symbol
# AC.TO    1617235200                839943000000          2  TIH.TO
#
# [1 rows x 70 columns]
#        language region quoteType quoteSourceName  triggerable currency  \
# AGI.TO    en-US     US    EQUITY   Delayed Quote         True      CAD
#
#        exchange     shortName                  longName messageBoardId  ...  \
# AGI.TO      TOR  TOROMONT IND  Toromont Industries Ltd.   finmb_873897  ...
#
#        fiftyTwoWeekLowChangePercent fiftyTwoWeekRange  fiftyTwoWeekHighChange  \
# AGI.TO                      0.62678    61.09 - 100.71               -1.330002
#
#        fiftyTwoWeekHighChangePercent  fiftyTwoWeekLow fiftyTwoWeekHigh  \
# AGI.TO                     -0.013206            61.09           100.71
#
#         dividendDate  firstTradeDateMilliseconds  priceHint  symbol
# AGI.TO    1617235200                839943000000          2  TIH.TO
#
# [1 rows x 70 columns]
#        language region quoteType quoteSourceName  triggerable currency  \
# AQN.TO    en-US     US    EQUITY   Delayed Quote         True      CAD
#
#        exchange     shortName                  longName messageBoardId  ...  \
# AQN.TO      TOR  TOROMONT IND  Toromont Industries Ltd.   finmb_873897  ...
#
#        fiftyTwoWeekLowChangePercent fiftyTwoWeekRange  fiftyTwoWeekHighChange  \
# AQN.TO                      0.62678    61.09 - 100.71               -1.330002
#
#        fiftyTwoWeekHighChangePercent  fiftyTwoWeekLow fiftyTwoWeekHigh  \
# AQN.TO                     -0.013206            61.09           100.71
#
#         dividendDate  firstTradeDateMilliseconds  priceHint  symbol
# AQN.TO    1617235200                839943000000          2  TIH.TO
#
# [1 rows x 70 columns]
# IndexErrorTraceback (most recent call last)
# <ipython-input-61-572065aeed1c> in <module>
#       2
#       3 for ticker in tsx_names:
# ----> 4     tickerDict = get_quote_data(ticker)
#       5     tickerdf = pd.DataFrame(dict1, index=[ticker])
#       6     print(tickerdf)
#
# ~\Anaconda3\envs\TSXStockClustering\lib\site-packages\yahoo_fin\stock_info.py in get_quote_data(ticker)
#     931     info = json_result["quoteResponse"]["result"]
#     932
# --> 933     return info[0]
#     934
#     935
#
# IndexError: list index out of range
